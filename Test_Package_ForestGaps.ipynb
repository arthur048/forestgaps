# %%
# !wget -O colab_install.py https://raw.githubusercontent.com/arthur048/forestgaps/main/colab_install.py
# %run colab_install.py
# Out:
# --2025-03-10 09:36:29--  https://raw.githubusercontent.com/arthur048/forestgaps/main/colab_install.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4662 (4.6K) [text/plain]
# Saving to: ‘colab_install.py’
#
# colab_install.py    100%[===================>]   4.55K  --.-KB/s    in 0s
#
# 2025-03-10 09:36:29 (12.0 MB/s) - ‘colab_install.py’ saved [4662/4662]
#
# ⚠️ Dépendances manquantes: rasterio
# 📦 Installation des dépendances manquantes...
# ✅ Dépendances installées.
# 🚀 Installation de ForestGaps-DL pour Google Colab...
# ✅ ForestGaps-DL installé avec succès (sans réinstaller les dépendances).
# ✅ Module forestgaps_dl importé avec succès (version: 0.1.1).
#
# ✅ Installation terminée avec succès!
# ℹ️ Pour utiliser ForestGaps-DL, redémarrez le runtime Colab, puis importez le module comme suit:
#
# from forestgaps_dl.environment import setup_environment
# env = setup_environment()

# %%
from forestgaps-dl.environment import setup_environment
env = setup_environment()
# Out:
# ✅ Environnement Google Colab détecté.
# Configuration de l'environnement Google Colab...
# ❌ Erreur lors du montage de Google Drive: Error: credential propagation was unsuccessful
# ⚠️ Impossible de monter Google Drive. Le stockage persistant ne sera pas disponible.
# ✅ torch est déjà installé.
# ✅ torchvision est déjà installé.
# ✅ numpy est déjà installé.
# ✅ matplotlib est déjà installé.
# ✅ rasterio est déjà installé.
# ✅ geopandas est déjà installé.
# ✅ PyYAML est déjà installé.
# ✅ pydantic est déjà installé.
# ✅ tqdm est déjà installé.
# ✅ tensorboard est déjà installé.
# ✅ Toutes les dépendances sont déjà installées.
# ❌ Aucun GPU détecté dans cet environnement Colab.
# ⚠️ Aucun GPU disponible. L'exécution sera plus lente.
# ✅ Configuration de l'environnement Colab terminée.

# %%
from forestgaps_dl.config import load_default_config
from forestgaps_dl.data.preprocessing import process_raster_pair_robustly
from forestgaps_dl.data.generation import create_gap_masks

# Charger la configuration par défaut
config = load_default_config()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-6c19e4d5a297> in <cell line: 0>()
# ----> 1 from forestgaps_dl.config import load_default_config
#       2 from forestgaps_dl.data.preprocessing import process_raster_pair_robustly
#       3 from forestgaps_dl.data.generation import create_gap_masks
#       4
#       5 # Charger la configuration par défaut
#
# ModuleNotFoundError: No module named 'forestgaps_dl.config'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
